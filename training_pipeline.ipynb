# %%
import numpy as np
import pandas as pd
import seaborn as sns
import string
import os
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from torch.autograd import Variable
from torchvision import transforms
from PIL import Image

# %%
use_cuda = torch.cuda.is_available()

print(use_cuda)
# Out:
# True

# %%
# classes' labels
sign_labels = ['A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'K', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'T', 'U', 'V', 'W', 'X', 'Y']  
#non-static signs excluded 

dict_alph = {
   'a' : 0,
   'b' : 1,
   'c' : 2,
   'd' : 3,
   'e' : 4,
   'f' : 5,
   'h' : 6,
   'i' : 7,
   'k' : 8,
   'l' : 9,
   'm' : 10,
   'n' : 11,
   'o' : 12,
   'p' : 13,
   'q' : 14,
   'r' : 15,
   't' : 16,
   'u' : 17,
   'v' : 18,
   'w' : 19,
   'x' : 20,
   'y' : 21
}

# size of our images.
img_width, img_height = 64, 64

# %%
### Dataset folder (images must be stored in sub-folders per letter)

DATASET_FOLDER= "./DatasetLIS/dataset1" 

#partition folders 
train_data_dir = DATASET_FOLDER + "/train"
validation_data_dir = DATASET_FOLDER + "/validation"
testing_data_dir = DATASET_FOLDER + "/testing"

# %%
###  Epochs and batch-size definition  
epochs = 60
batch_size = 64
# input_shape = (3,64,64)

# %%
# from model.model_def_v2 import MyModel
from model.model_def_v1 import SignLanguageCNN
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    model = SignLanguageCNN().cuda()
else:
    model = SignLanguageCNN()

# %%
# summary(model) #takes the model and the input tensor shape, displays the output shape

# %%
from torchvision.io import read_image
from torchvision import transforms

def get_dataset(path_directory):

   transform = transforms.Compose([ transforms.Grayscale(),
                                    transforms.Resize((64, 64)),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(15),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.485,), (0.229,)) ]) # @TODO: compute actual norm and devstd of the dataset
    
   print(path_directory)
   data = []
   labels = []
   img_train = []

   for folder in os.listdir(path_directory):
      subpath = path_directory+'/'+folder

      for img_name in os.listdir(subpath):
         #print(img_name)
         #im = read_image(subpath + '/'+ img_name)
         im = transform(Image.open(subpath + '/'+ img_name))
         label = dict_alph[img_name[0]]
         labels.append(label)
         img_train.append(im)
         
         data.append((im,label)) 

   return data, img_train, labels

# %%
train_data, imgs_train, labels_train = get_dataset(train_data_dir)
test_data, imgs_test, labels_test = get_dataset(testing_data_dir)
# Out:
# ./DatasetLIS/dataset1/train
# ./DatasetLIS/dataset1/testing

# %%
from torch.utils.data import DataLoader
train_data = DataLoader(train_data, batch_size=batch_size, num_workers=2, shuffle=True)
test_data = DataLoader(test_data, batch_size=batch_size, num_workers=2)

# %%
import torch
import torch.nn as nn
from torch.optim import SGD
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import accuracy_score
from os.path import join
import tqdm
import numpy as np

class AverageValueMeter:
    def __init__(self):
        self.reset()
        self.sum = 0
        self.num = 0

    def reset(self):
        self.sum = 0
        self.num = 0

    def add(self, val, n=1):
        self.sum += val*n
        self.num += n

    def value(self):
        try:
            return self.sum/self.num
        except:
            return None


def train_classifier(model, train_loader, test_loader, exp_name='experiment', lr=0.01, epochs=10, momentum=0.99, logdir='logs'):
    # optimizer = SGD(model.parameters(), lr=lr, momentum=momentum)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
    criterion = nn.CrossEntropyLoss()
    writer = SummaryWriter(join(logdir, exp_name))
    loss_meter = AverageValueMeter()
    acc_meter = AverageValueMeter()
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print("Device:", device)
    model.to(device)

    loader = {
        'train': train_loader,
        'test': test_loader
    }

    global_step = 0

    for e in range(epochs):
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            loss_meter.reset()
            acc_meter.reset()

            with torch.set_grad_enabled(phase=='train'):
                with tqdm.tqdm(enumerate(loader[phase]), total=len(loader[phase]), desc=f"{phase.capitalize()} Epoch {e+1}/{epochs}", unit="batch") as pbar:
                    for i, batch in pbar:
                        
                        x = batch[0].to(device)
                        y = batch[1].to(device)
                        output = model(x)

                        n = x.shape[0]
                        global_step += n
                        loss = criterion(output, y)

                        if phase == 'train':
                            loss.backward()
                            optimizer.step()
                            optimizer.zero_grad()
                            # scheduler.step(loss)

                        accuracy = accuracy_score(y.to('cpu'), output.to('cpu').max(1)[1])
                        loss_meter.add(loss.item(), n)
                        acc_meter.add(accuracy, n)

                        pbar.set_postfix(loss=loss_meter.value(), accuracy=acc_meter.value())

                        if phase == 'train':
                            writer.add_scalar('loss/train', loss_meter.value(), global_step=global_step)
                            writer.add_scalar('accuracy/train', acc_meter.value(), global_step=global_step)
            writer.add_scalar('loss/' + phase, loss_meter.value(), global_step=global_step)
            writer.add_scalar('accuracy/' + phase, acc_meter.value(), global_step=global_step)

        torch.save(model.state_dict(), '%s-%d.pth' % (exp_name, e+1))

    return model

def test_classifier_v2(model, loader):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    model.to(device)
    model.eval()

    predictions, labels = [], []

    with torch.no_grad():
        with tqdm.tqdm(loader, desc="Testing", unit="batch") as pbar:
            for batch in pbar:
                x = batch[0].to(device)
                y = batch[1].to(device)
                output = model(x)
                preds = output.to("cpu").max(dim=1)[1]
                labs = y.to("cpu").numpy()
                predictions.extend(list(preds))
                labels.extend(list(labs))

    return np.array(predictions), np.array(labels)

# %%
input_shape = (3, 64, 64) # Channels, Height, Width
model = SignLanguageCNN()

train_classifier(model, train_data, test_data, epochs=epochs, lr=0.001, logdir="Prima Prova")

test_result = test_classifier_v2(model, test_data)
# Out:
# Device: cuda
# Train Epoch 1/60: 100%|██████████| 95/95 [00:02<00:00, 33.97batch/s, accuracy=0.0722, loss=3.09]
# Test Epoch 1/60: 100%|██████████| 20/20 [00:00<00:00, 20.29batch/s, accuracy=0.139, loss=2.75]
# Train Epoch 2/60: 100%|██████████| 95/95 [00:02<00:00, 34.46batch/s, accuracy=0.135, loss=2.63]
# Test Epoch 2/60: 100%|██████████| 20/20 [00:01<00:00, 18.70batch/s, accuracy=0.234, loss=2.29]
# Train Epoch 3/60: 100%|██████████| 95/95 [00:02<00:00, 34.75batch/s, accuracy=0.199, loss=2.29]
# Test Epoch 3/60: 100%|██████████| 20/20 [00:00<00:00, 20.49batch/s, accuracy=0.3, loss=1.97]
# Train Epoch 4/60: 100%|██████████| 95/95 [00:02<00:00, 35.46batch/s, accuracy=0.274, loss=2.03]
# Test Epoch 4/60: 100%|██████████| 20/20 [00:00<00:00, 20.79batch/s, accuracy=0.339, loss=1.87]
# Train Epoch 5/60: 100%|██████████| 95/95 [00:02<00:00, 34.75batch/s, accuracy=0.328, loss=1.85]
# Test Epoch 5/60: 100%|██████████| 20/20 [00:01<00:00, 18.72batch/s, accuracy=0.374, loss=1.6]
# Train Epoch 6/60: 100%|██████████| 95/95 [00:02<00:00, 34.12batch/s, accuracy=0.369, loss=1.69]
# Test Epoch 6/60: 100%|██████████| 20/20 [00:01<00:00, 19.35batch/s, accuracy=0.451, loss=1.51]
# Train Epoch 7/60: 100%|██████████| 95/95 [00:02<00:00, 34.95batch/s, accuracy=0.416, loss=1.58]
# Test Epoch 7/60: 100%|██████████| 20/20 [00:01<00:00, 19.23batch/s, accuracy=0.49, loss=1.4]
# Train Epoch 8/60: 100%|██████████| 95/95 [00:02<00:00, 35.11batch/s, accuracy=0.45, loss=1.48]
# Test Epoch 8/60: 100%|██████████| 20/20 [00:01<00:00, 19.80batch/s, accuracy=0.507, loss=1.42]
# Train Epoch 9/60: 100%|██████████| 95/95 [00:02<00:00, 35.00batch/s, accuracy=0.49, loss=1.36]
# Test Epoch 9/60: 100%|██████████| 20/20 [00:00<00:00, 20.37batch/s, accuracy=0.58, loss=1.13]
# Train Epoch 10/60: 100%|██████████| 95/95 [00:02<00:00, 35.50batch/s, accuracy=0.53, loss=1.25]
# Test Epoch 10/60: 100%|██████████| 20/20 [00:00<00:00, 20.36batch/s, accuracy=0.544, loss=1.29]
# Train Epoch 11/60: 100%|██████████| 95/95 [00:02<00:00, 36.25batch/s, accuracy=0.546, loss=1.19]
# Test Epoch 11/60: 100%|██████████| 20/20 [00:00<00:00, 20.00batch/s, accuracy=0.619, loss=1.02]
# Train Epoch 12/60: 100%|██████████| 95/95 [00:02<00:00, 35.38batch/s, accuracy=0.562, loss=1.16]
# Test Epoch 12/60: 100%|██████████| 20/20 [00:01<00:00, 19.92batch/s, accuracy=0.639, loss=0.986]
# Train Epoch 13/60: 100%|██████████| 95/95 [00:02<00:00, 35.41batch/s, accuracy=0.597, loss=1.04]
# Test Epoch 13/60: 100%|██████████| 20/20 [00:00<00:00, 20.04batch/s, accuracy=0.657, loss=1]
# Train Epoch 14/60: 100%|██████████| 95/95 [00:02<00:00, 35.08batch/s, accuracy=0.62, loss=0.991]
# Test Epoch 14/60: 100%|██████████| 20/20 [00:00<00:00, 20.43batch/s, accuracy=0.625, loss=1.09]
# Train Epoch 15/60: 100%|██████████| 95/95 [00:02<00:00, 35.35batch/s, accuracy=0.642, loss=0.962]
# Test Epoch 15/60: 100%|██████████| 20/20 [00:00<00:00, 20.35batch/s, accuracy=0.713, loss=0.784]
# Train Epoch 16/60: 100%|██████████| 95/95 [00:02<00:00, 35.00batch/s, accuracy=0.661, loss=0.914]
# Test Epoch 16/60: 100%|██████████| 20/20 [00:01<00:00, 19.68batch/s, accuracy=0.729, loss=0.741]
# Train Epoch 17/60: 100%|██████████| 95/95 [00:02<00:00, 34.90batch/s, accuracy=0.688, loss=0.822]
# Test Epoch 17/60: 100%|██████████| 20/20 [00:00<00:00, 20.36batch/s, accuracy=0.759, loss=0.682]
# Train Epoch 18/60: 100%|██████████| 95/95 [00:02<00:00, 35.01batch/s, accuracy=0.69, loss=0.815]
# Test Epoch 18/60: 100%|██████████| 20/20 [00:01<00:00, 19.57batch/s, accuracy=0.775, loss=0.662]
# Train Epoch 19/60: 100%|██████████| 95/95 [00:02<00:00, 34.91batch/s, accuracy=0.717, loss=0.753]
# Test Epoch 19/60: 100%|██████████| 20/20 [00:00<00:00, 20.42batch/s, accuracy=0.724, loss=0.807]
# Train Epoch 20/60: 100%|██████████| 95/95 [00:02<00:00, 37.30batch/s, accuracy=0.748, loss=0.673]
# Test Epoch 20/60: 100%|██████████| 20/20 [00:01<00:00, 20.00batch/s, accuracy=0.774, loss=0.631]
# Train Epoch 21/60: 100%|██████████| 95/95 [00:02<00:00, 34.86batch/s, accuracy=0.75, loss=0.663]
# Test Epoch 21/60: 100%|██████████| 20/20 [00:00<00:00, 20.38batch/s, accuracy=0.772, loss=0.622]
# Train Epoch 22/60: 100%|██████████| 95/95 [00:02<00:00, 36.91batch/s, accuracy=0.763, loss=0.619]
# Test Epoch 22/60: 100%|██████████| 20/20 [00:00<00:00, 20.20batch/s, accuracy=0.814, loss=0.558]
# Train Epoch 23/60: 100%|██████████| 95/95 [00:02<00:00, 35.08batch/s, accuracy=0.776, loss=0.616]
# Test Epoch 23/60: 100%|██████████| 20/20 [00:00<00:00, 20.09batch/s, accuracy=0.787, loss=0.635]
# Train Epoch 24/60: 100%|██████████| 95/95 [00:02<00:00, 36.07batch/s, accuracy=0.793, loss=0.559]
# Test Epoch 24/60: 100%|██████████| 20/20 [00:01<00:00, 19.97batch/s, accuracy=0.827, loss=0.493]
# Train Epoch 25/60: 100%|██████████| 95/95 [00:02<00:00, 35.16batch/s, accuracy=0.817, loss=0.499]
# Test Epoch 25/60: 100%|██████████| 20/20 [00:00<00:00, 20.69batch/s, accuracy=0.803, loss=0.615]
# Train Epoch 26/60: 100%|██████████| 95/95 [00:02<00:00, 34.47batch/s, accuracy=0.81, loss=0.507]
# Test Epoch 26/60: 100%|██████████| 20/20 [00:01<00:00, 19.93batch/s, accuracy=0.816, loss=0.525]
# Train Epoch 27/60: 100%|██████████| 95/95 [00:02<00:00, 35.25batch/s, accuracy=0.841, loss=0.434]
# Test Epoch 27/60: 100%|██████████| 20/20 [00:00<00:00, 20.17batch/s, accuracy=0.83, loss=0.503]
# Train Epoch 28/60: 100%|██████████| 95/95 [00:02<00:00, 34.85batch/s, accuracy=0.848, loss=0.425]
# Test Epoch 28/60: 100%|██████████| 20/20 [00:00<00:00, 20.91batch/s, accuracy=0.838, loss=0.471]
# Train Epoch 29/60: 100%|██████████| 95/95 [00:02<00:00, 35.24batch/s, accuracy=0.848, loss=0.43]
# Test Epoch 29/60: 100%|██████████| 20/20 [00:00<00:00, 20.70batch/s, accuracy=0.803, loss=0.596]
# Train Epoch 30/60: 100%|██████████| 95/95 [00:02<00:00, 35.08batch/s, accuracy=0.844, loss=0.423]
# Test Epoch 30/60: 100%|██████████| 20/20 [00:00<00:00, 20.32batch/s, accuracy=0.866, loss=0.428]
# Train Epoch 31/60: 100%|██████████| 95/95 [00:02<00:00, 35.69batch/s, accuracy=0.847, loss=0.417]
# Test Epoch 31/60: 100%|██████████| 20/20 [00:00<00:00, 20.09batch/s, accuracy=0.782, loss=0.662]
# Train Epoch 32/60: 100%|██████████| 95/95 [00:02<00:00, 35.96batch/s, accuracy=0.867, loss=0.375]
# Test Epoch 32/60: 100%|██████████| 20/20 [00:01<00:00, 19.61batch/s, accuracy=0.851, loss=0.441]
# Train Epoch 33/60: 100%|██████████| 95/95 [00:02<00:00, 36.10batch/s, accuracy=0.881, loss=0.342]
# Test Epoch 33/60: 100%|██████████| 20/20 [00:01<00:00, 19.78batch/s, accuracy=0.872, loss=0.411]
# Train Epoch 34/60: 100%|██████████| 95/95 [00:02<00:00, 34.24batch/s, accuracy=0.885, loss=0.324]
# Test Epoch 34/60: 100%|██████████| 20/20 [00:01<00:00, 19.21batch/s, accuracy=0.856, loss=0.461]
# Train Epoch 35/60: 100%|██████████| 95/95 [00:02<00:00, 35.46batch/s, accuracy=0.886, loss=0.319]
# Test Epoch 35/60: 100%|██████████| 20/20 [00:01<00:00, 17.89batch/s, accuracy=0.88, loss=0.373]
# Train Epoch 36/60: 100%|██████████| 95/95 [00:02<00:00, 34.08batch/s, accuracy=0.886, loss=0.332]
# Test Epoch 36/60: 100%|██████████| 20/20 [00:00<00:00, 20.31batch/s, accuracy=0.827, loss=0.515]
# Train Epoch 37/60: 100%|██████████| 95/95 [00:02<00:00, 35.33batch/s, accuracy=0.894, loss=0.311]
# Test Epoch 37/60: 100%|██████████| 20/20 [00:00<00:00, 20.43batch/s, accuracy=0.857, loss=0.438]
# Train Epoch 38/60: 100%|██████████| 95/95 [00:02<00:00, 35.44batch/s, accuracy=0.9, loss=0.284]
# Test Epoch 38/60: 100%|██████████| 20/20 [00:01<00:00, 19.55batch/s, accuracy=0.821, loss=0.608]
# Train Epoch 39/60: 100%|██████████| 95/95 [00:02<00:00, 34.27batch/s, accuracy=0.891, loss=0.317]
# Test Epoch 39/60: 100%|██████████| 20/20 [00:00<00:00, 20.12batch/s, accuracy=0.868, loss=0.409]
# Train Epoch 40/60: 100%|██████████| 95/95 [00:02<00:00, 35.49batch/s, accuracy=0.908, loss=0.263]
# Test Epoch 40/60: 100%|██████████| 20/20 [00:01<00:00, 19.87batch/s, accuracy=0.869, loss=0.413]
# Train Epoch 41/60: 100%|██████████| 95/95 [00:02<00:00, 35.38batch/s, accuracy=0.916, loss=0.241]
# Test Epoch 41/60: 100%|██████████| 20/20 [00:01<00:00, 19.22batch/s, accuracy=0.87, loss=0.413]
# Train Epoch 42/60: 100%|██████████| 95/95 [00:02<00:00, 34.69batch/s, accuracy=0.916, loss=0.246]
# Test Epoch 42/60: 100%|██████████| 20/20 [00:01<00:00, 19.49batch/s, accuracy=0.797, loss=0.721]
# Train Epoch 43/60: 100%|██████████| 95/95 [00:02<00:00, 33.07batch/s, accuracy=0.919, loss=0.232]
# Test Epoch 43/60: 100%|██████████| 20/20 [00:01<00:00, 19.58batch/s, accuracy=0.854, loss=0.479]
# Train Epoch 44/60: 100%|██████████| 95/95 [00:02<00:00, 33.46batch/s, accuracy=0.914, loss=0.245]
# Test Epoch 44/60: 100%|██████████| 20/20 [00:01<00:00, 18.85batch/s, accuracy=0.868, loss=0.435]
# Train Epoch 45/60: 100%|██████████| 95/95 [00:02<00:00, 33.90batch/s, accuracy=0.933, loss=0.2]
# Test Epoch 45/60: 100%|██████████| 20/20 [00:01<00:00, 18.89batch/s, accuracy=0.887, loss=0.362]
# Train Epoch 46/60: 100%|██████████| 95/95 [00:02<00:00, 32.97batch/s, accuracy=0.931, loss=0.2]
# Test Epoch 46/60: 100%|██████████| 20/20 [00:01<00:00, 18.90batch/s, accuracy=0.874, loss=0.436]
# Train Epoch 47/60: 100%|██████████| 95/95 [00:02<00:00, 32.86batch/s, accuracy=0.927, loss=0.218]
# Test Epoch 47/60: 100%|██████████| 20/20 [00:01<00:00, 18.89batch/s, accuracy=0.863, loss=0.432]
# Train Epoch 48/60: 100%|██████████| 95/95 [00:02<00:00, 34.42batch/s, accuracy=0.924, loss=0.215]
# Test Epoch 48/60: 100%|██████████| 20/20 [00:01<00:00, 19.35batch/s, accuracy=0.868, loss=0.433]
# Train Epoch 49/60: 100%|██████████| 95/95 [00:02<00:00, 31.72batch/s, accuracy=0.926, loss=0.229]
# Test Epoch 49/60: 100%|██████████| 20/20 [00:01<00:00, 18.52batch/s, accuracy=0.882, loss=0.366]
# Train Epoch 50/60: 100%|██████████| 95/95 [00:02<00:00, 32.87batch/s, accuracy=0.93, loss=0.204]
# Test Epoch 50/60: 100%|██████████| 20/20 [00:01<00:00, 17.23batch/s, accuracy=0.888, loss=0.413]
# Train Epoch 51/60: 100%|██████████| 95/95 [00:02<00:00, 32.49batch/s, accuracy=0.931, loss=0.204]
# Test Epoch 51/60: 100%|██████████| 20/20 [00:01<00:00, 18.70batch/s, accuracy=0.87, loss=0.393]
# Train Epoch 52/60: 100%|██████████| 95/95 [00:02<00:00, 32.49batch/s, accuracy=0.932, loss=0.197]
# Test Epoch 52/60: 100%|██████████| 20/20 [00:01<00:00, 18.40batch/s, accuracy=0.881, loss=0.371]
# Train Epoch 53/60: 100%|██████████| 95/95 [00:02<00:00, 32.85batch/s, accuracy=0.931, loss=0.207]
# Test Epoch 53/60: 100%|██████████| 20/20 [00:01<00:00, 19.26batch/s, accuracy=0.874, loss=0.381]
# Train Epoch 54/60: 100%|██████████| 95/95 [00:02<00:00, 31.86batch/s, accuracy=0.945, loss=0.166]
# Test Epoch 54/60: 100%|██████████| 20/20 [00:01<00:00, 18.81batch/s, accuracy=0.879, loss=0.438]
# Train Epoch 55/60: 100%|██████████| 95/95 [00:03<00:00, 31.19batch/s, accuracy=0.952, loss=0.147]
# Test Epoch 55/60: 100%|██████████| 20/20 [00:01<00:00, 18.50batch/s, accuracy=0.895, loss=0.354]
# Train Epoch 56/60: 100%|██████████| 95/95 [00:02<00:00, 33.90batch/s, accuracy=0.94, loss=0.187]
# Test Epoch 56/60: 100%|██████████| 20/20 [00:01<00:00, 19.78batch/s, accuracy=0.91, loss=0.294]
# Train Epoch 57/60: 100%|██████████| 95/95 [00:02<00:00, 33.80batch/s, accuracy=0.938, loss=0.193]
# Test Epoch 57/60: 100%|██████████| 20/20 [00:01<00:00, 19.33batch/s, accuracy=0.898, loss=0.357]
# Train Epoch 58/60: 100%|██████████| 95/95 [00:02<00:00, 32.84batch/s, accuracy=0.931, loss=0.211]
# Test Epoch 58/60: 100%|██████████| 20/20 [00:01<00:00, 19.20batch/s, accuracy=0.859, loss=0.47]
# Train Epoch 59/60: 100%|██████████| 95/95 [00:02<00:00, 33.54batch/s, accuracy=0.941, loss=0.172]
# Test Epoch 59/60: 100%|██████████| 20/20 [00:01<00:00, 19.65batch/s, accuracy=0.856, loss=0.519]
# Train Epoch 60/60: 100%|██████████| 95/95 [00:02<00:00, 33.99batch/s, accuracy=0.946, loss=0.169]
# Test Epoch 60/60: 100%|██████████| 20/20 [00:01<00:00, 19.40batch/s, accuracy=0.883, loss=0.409]
# Testing: 100%|██████████| 20/20 [00:02<00:00,  6.90batch/s]

# %%
# print all test results in a for loop
counter = 0
for i in range(len(test_result[0])):
    if (sign_labels[test_result[0][i]] == sign_labels[test_result[1][i]]):
        counter += 1
    print("Predicted: ", sign_labels[test_result[0][i]], "Actual: ", sign_labels[test_result[1][i]])

print(counter / len(test_result[0]), " || ", counter, "/", len(test_result[0]))
# Out:
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  F Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  Y Actual:  A
# Predicted:  Y Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  A Actual:  A
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  U Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  B Actual:  B
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  O Actual:  C
# Predicted:  C Actual:  C
# Predicted:  O Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  O Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  O Actual:  C
# Predicted:  C Actual:  C
# Predicted:  O Actual:  C
# Predicted:  O Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  E Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  C Actual:  C
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  U Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  U Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  K Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  I Actual:  D
# Predicted:  D Actual:  D
# Predicted:  I Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  R Actual:  D
# Predicted:  U Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  K Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  K Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  D Actual:  D
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  B Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  A Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  B Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  E Actual:  E
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  B Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  R Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  K Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  R Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  F Actual:  F
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  O Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  R Actual:  H
# Predicted:  U Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  Q Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  K Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  P Actual:  H
# Predicted:  Y Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  H Actual:  H
# Predicted:  F Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  U Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  D Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  A Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  I Actual:  I
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  P Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  V Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  T Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  P Actual:  K
# Predicted:  T Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  K Actual:  K
# Predicted:  I Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  V Actual:  L
# Predicted:  V Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  Y Actual:  L
# Predicted:  Y Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  K Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  V Actual:  L
# Predicted:  L Actual:  L
# Predicted:  V Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  L Actual:  L
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  M
# Predicted:  M Actual:  M
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  N Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  Q Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  N Actual:  N
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  Q Actual:  O
# Predicted:  Q Actual:  O
# Predicted:  O Actual:  O
# Predicted:  O Actual:  O
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  Q Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  Q Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  K Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  P Actual:  P
# Predicted:  Q Actual:  P
# Predicted:  P Actual:  P
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  N Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  M Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  Q Actual:  Q
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  F Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  V Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  K Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  U Actual:  R
# Predicted:  U Actual:  R
# Predicted:  R Actual:  R
# Predicted:  U Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  R Actual:  R
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  K Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  A Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  H Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  P Actual:  T
# Predicted:  P Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  T Actual:  T
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  R Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  R Actual:  U
# Predicted:  R Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  V Actual:  U
# Predicted:  U Actual:  U
# Predicted:  V Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  V Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  U Actual:  U
# Predicted:  R Actual:  U
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  W Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  D Actual:  V
# Predicted:  D Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  K Actual:  V
# Predicted:  V Actual:  V
# Predicted:  W Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  I Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  U Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  V Actual:  V
# Predicted:  U Actual:  V
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  B Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  V Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  W Actual:  W
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  K Actual:  X
# Predicted:  I Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  K Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  T Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  K Actual:  X
# Predicted:  I Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  X Actual:  X
# Predicted:  R Actual:  X
# Predicted:  X Actual:  X
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  A Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  P Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  I Actual:  Y
# Predicted:  I Actual:  Y
# Predicted:  I Actual:  Y
# Predicted:  I Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# Predicted:  Y Actual:  Y
# 0.8827868852459017  ||  1077 / 1220

# %%
torch.save(model, 'bello_modello.pt')
